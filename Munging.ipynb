# %% [markdown]
# # Data Consolidation
# #### Building a Dataset

# %%
# library load
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
elim_data = pd.read_csv('bachelorette_538.csv')
# remove first line, which is just the header info repeated
elim_data = elim_data.drop([0])
elim_data.head()
# Out:
#            SHOW SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 1  Bachelorette     13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette     13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette     13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette     13   13_DEAN_U           NaN             R           NaN
# 5  Bachelorette     13   13_ADAM_G           NaN           NaN           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7   ...    DATES-1  \
# 1             R             R           NaN             R   ...        NaN
# 2           NaN           NaN             R             R   ...        NaN
# 3           NaN           NaN             R             R   ...        NaN
# 4             R           NaN           NaN             R   ...        NaN
# 5           NaN           NaN           NaN            ED   ...        NaN
#
#   DATES-2 DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8 DATES-9 DATES-10
# 1     NaN      D6     D13      D1      D7      D1      D1      D1       D1
# 2      D1      D6     D13      D9      D7      D1      D1      D1       D1
# 3     D10      D8     D13      D9      D1      D3      D1      D1      NaN
# 4      D8      D8      D1      D9      D7      D1      D1     NaN      NaN
# 5     D10      D8     D13      D9      D7      D3     NaN     NaN      NaN
#
# [5 rows x 23 columns]

# %%
# need to change from wide form data to long form data
# want it to be:
# SHOW, SEASON, CONTESTANT, 'TYPE', 'VALUE'
# with 'TYPE' as the current column names
elim1 = pd.melt(elim_data, id_vars=['SHOW', 'SEASON', 'CONTESTANT'])
elim1.head()
# Out:
#            SHOW SEASON  CONTESTANT       variable value
# 0  Bachelorette     13  13_BRYAN_A  ELIMINATION-1    R1
# 1  Bachelorette     13  13_PETER_K  ELIMINATION-1   NaN
# 2  Bachelorette     13   13_ERIC_B  ELIMINATION-1   NaN
# 3  Bachelorette     13   13_DEAN_U  ELIMINATION-1   NaN
# 4  Bachelorette     13   13_ADAM_G  ELIMINATION-1   NaN

# %%
# rename variable and value
elim1.columns = ['SHOW', 'SEASON', 'CONTESTANT', 'TYPE', 'VALUE']
elim1.head()
# Out:
#            SHOW SEASON  CONTESTANT           TYPE VALUE
# 0  Bachelorette     13  13_BRYAN_A  ELIMINATION-1    R1
# 1  Bachelorette     13  13_PETER_K  ELIMINATION-1   NaN
# 2  Bachelorette     13   13_ERIC_B  ELIMINATION-1   NaN
# 3  Bachelorette     13   13_DEAN_U  ELIMINATION-1   NaN
# 4  Bachelorette     13   13_ADAM_G  ELIMINATION-1   NaN

# %%
# split TYPE variable
elim1[['ELIM_DATE', 'NUMBER']] = elim1['TYPE'].str.split('-',expand=True)

# %%
elim1.head()
# Out:
#            SHOW SEASON  CONTESTANT           TYPE VALUE    ELIM_DATE NUMBER
# 0  Bachelorette     13  13_BRYAN_A  ELIMINATION-1    R1  ELIMINATION      1
# 1  Bachelorette     13  13_PETER_K  ELIMINATION-1   NaN  ELIMINATION      1
# 2  Bachelorette     13   13_ERIC_B  ELIMINATION-1   NaN  ELIMINATION      1
# 3  Bachelorette     13   13_DEAN_U  ELIMINATION-1   NaN  ELIMINATION      1
# 4  Bachelorette     13   13_ADAM_G  ELIMINATION-1   NaN  ELIMINATION      1

# %%
elim1.to_csv("elimination_long_form.csv")

# %% [markdown]
# ### this is the information we need to model 'survival'

# %% [markdown]
# # Need to Bring In the Contestant & Bachelor/ette data
# #### modify region/state and occupation
# ### Then combine it to create a possible demographic predictive set
# #### and make some other possible useful variables

# %%
bach = pd.read_csv("bachelors.csv")
bach_cont = pd.read_csv("bachelor-contestants.csv")
ette = pd.read_csv("bachelorettes.csv")
ette_cont = pd.read_csv("bachelorette-contestants.csv")

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %% [markdown]
# ### Bachelors First

# %%
bach.head()
# Out:
#                Name  Age                   Hometown  Height  Season
# 0       Alex Michel   32  Charlottesville, Virginia     NaN       1
# 1      Aaron Buerge   28           Butler, Missouri     NaN       2
# 2      Jesse Palmer   34           Toronto, Ontario     NaN       5
# 3  Lorenzo Borghese   34               Milan, Italy     NaN       9
# 4      Andy Baldwin   30    Lancaster, Pennsylvania     NaN      10

# %%
# Split Hometown column
bach[['Hometown_City', 'Hometown_State']] = bach['Hometown'].str.split(', ',expand=True)
bach.head()
# Out:
#                Name  Age                   Hometown  Height  Season  \
# 0       Alex Michel   32  Charlottesville, Virginia     NaN       1
# 1      Aaron Buerge   28           Butler, Missouri     NaN       2
# 2      Jesse Palmer   34           Toronto, Ontario     NaN       5
# 3  Lorenzo Borghese   34               Milan, Italy     NaN       9
# 4      Andy Baldwin   30    Lancaster, Pennsylvania     NaN      10
#
#      Hometown_City Hometown_State
# 0  Charlottesville       Virginia
# 1           Butler       Missouri
# 2          Toronto        Ontario
# 3            Milan          Italy
# 4        Lancaster   Pennsylvania

# %%
# Convert Hometown_State to us state abbreviation if relevant
StateAbbrev = []
for index, row in bach.iterrows():
    #print(row['c1'], row['c2'])
    if row['Hometown_State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['Hometown_State']])
    else: 
        StateAbbrev.append(row['Hometown_State'])
        
bach['Hometown_StateAbbrev'] = StateAbbrev
bach.head()
# Out:
#                Name  Age                   Hometown  Height  Season  \
# 0       Alex Michel   32  Charlottesville, Virginia     NaN       1
# 1      Aaron Buerge   28           Butler, Missouri     NaN       2
# 2      Jesse Palmer   34           Toronto, Ontario     NaN       5
# 3  Lorenzo Borghese   34               Milan, Italy     NaN       9
# 4      Andy Baldwin   30    Lancaster, Pennsylvania     NaN      10
#
#      Hometown_City Hometown_State Hometown_StateAbbrev
# 0  Charlottesville       Virginia                   VA
# 1           Butler       Missouri                   MO
# 2          Toronto        Ontario              Ontario
# 3            Milan          Italy                Italy
# 4        Lancaster   Pennsylvania                   PA

# %% [markdown]
# ### Variables We'll Keep:
# #### Name
# #### Age
# #### Height
# #### Season
# #### Hometown_City
# #### Hometown_StateAbbrev
#
# ###### Removing the summary Hometown column (we've broken it up), Hometown_State (because we're using the abbreviation version instead)

# %%
final_bach = bach[['Name', 'Age', 'Height', 'Season', 'Hometown_City', 'Hometown_StateAbbrev']].copy()
final_bach.columns = ['BACHELOR', 'BACHELOR_AGE', 'BACHELOR_HEIGHT', 'SEASON', 'BACHELOR_HOMETOWN_CITY', 'BACHELOR_HOMETOWN_STATE']
final_bach.head()
# Out:
#            BACHELOR  BACHELOR_AGE  BACHELOR_HEIGHT  SEASON  \
# 0       Alex Michel            32              NaN       1
# 1      Aaron Buerge            28              NaN       2
# 2      Jesse Palmer            34              NaN       5
# 3  Lorenzo Borghese            34              NaN       9
# 4      Andy Baldwin            30              NaN      10
#
#   BACHELOR_HOMETOWN_CITY BACHELOR_HOMETOWN_STATE
# 0        Charlottesville                      VA
# 1                 Butler                      MO
# 2                Toronto                 Ontario
# 3                  Milan                   Italy
# 4              Lancaster                      PA

# %% [markdown]
# ### Bachelor Contestants

# %%
bach_cont.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season
# 0       Chanute, Kansas     NaN       NaN       1
# 1        Miami, Florida     NaN       6.0       1
# 2         Dallas, Texas     NaN       5.0       1
# 3        Tempe, Arizona     NaN       4.0       1
# 4  Terra Haute, Indiana     NaN       3.0       1

# %%
bach_cont['Height'].value_counts()
# Out:
# 67.00    6
# 64.00    5
# 65.00    3
# 62.00    3
# 66.00    3
# 68.00    2
# 61.00    2
# 67.75    1
# 63.50    1
# 63.00    1
# 62.50    1
# 70.00    1
# 67.50    1
# Name: Height, dtype: int64

# %%
# Split Hometown column
bach_cont[['Hometown_City', 'Hometown_State', 'Other']] = bach_cont['Hometown'].str.split(', ',expand=True)
bach_cont.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season Hometown_City  \
# 0       Chanute, Kansas     NaN       NaN       1       Chanute
# 1        Miami, Florida     NaN       6.0       1         Miami
# 2         Dallas, Texas     NaN       5.0       1        Dallas
# 3        Tempe, Arizona     NaN       4.0       1         Tempe
# 4  Terra Haute, Indiana     NaN       3.0       1   Terra Haute
#
#   Hometown_State Other
# 0         Kansas  None
# 1        Florida  None
# 2          Texas  None
# 3        Arizona  None
# 4        Indiana  None

# %%
bach_cont['Other'].value_counts()
# we can just drop this
# Out:
# Canada    2
# Name: Other, dtype: int64

# %%
# Convert Hometown_State to us state abbreviation if relevant
StateAbbrev = []
for index, row in bach_cont.iterrows():
    #print(row['c1'], row['c2'])
    if row['Hometown_State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['Hometown_State']])
    else: 
        StateAbbrev.append(row['Hometown_State'])
        
bach_cont['Hometown_StateAbbrev'] = StateAbbrev
bach_cont.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season Hometown_City  \
# 0       Chanute, Kansas     NaN       NaN       1       Chanute
# 1        Miami, Florida     NaN       6.0       1         Miami
# 2         Dallas, Texas     NaN       5.0       1        Dallas
# 3        Tempe, Arizona     NaN       4.0       1         Tempe
# 4  Terra Haute, Indiana     NaN       3.0       1   Terra Haute
#
#   Hometown_State Other Hometown_StateAbbrev
# 0         Kansas  None                   KS
# 1        Florida  None                   FL
# 2          Texas  None                   TX
# 3        Arizona  None                   AZ
# 4        Indiana  None                   IN

# %%
final_cont = bach_cont[['Name', 'Age', 'Occupation', 'Height', 'Season', 'ElimWeek', 'Hometown_City', 'Hometown_StateAbbrev']].copy()
final_cont.columns = ['CONTESTANT', 'CONTESTANT_AGE', 'CONTESTANT_JOB', 'CONTESTANT_HEIGHT', 'SEASON', 'CONTESTANT_ELIMWEEK', 'CONTESTANT_HOMETOWN_CITY', 'CONTESTANT_HOMETOWN_STATE']
final_cont.head()
# Out:
#        CONTESTANT  CONTESTANT_AGE                   CONTESTANT_JOB  \
# 0    Amanda Marsh            23.0                    Event Planner
# 1     Trista Rehn            29.0                Miami Heat Dancer
# 2  Shannon Oliver            24.0  Financial Management Consultant
# 3             Kim            24.0                            Nanny
# 4    Cathy Grimes            22.0                 Graduate Student
#
#    CONTESTANT_HEIGHT  SEASON  CONTESTANT_ELIMWEEK CONTESTANT_HOMETOWN_CITY  \
# 0                NaN       1                  NaN                  Chanute
# 1                NaN       1                  6.0                    Miami
# 2                NaN       1                  5.0                   Dallas
# 3                NaN       1                  4.0                    Tempe
# 4                NaN       1                  3.0              Terra Haute
#
#   CONTESTANT_HOMETOWN_STATE
# 0                        KS
# 1                        FL
# 2                        TX
# 3                        AZ
# 4                        IN

# %% [markdown]
# ##### Merge final_bach and final_cont on SEASON

# %%
the_bachelor = final_bach.merge(final_cont, on='SEASON')
print(the_bachelor.shape)
the_bachelor.head()
# Out:
# (423, 13)
#       BACHELOR  BACHELOR_AGE  BACHELOR_HEIGHT  SEASON BACHELOR_HOMETOWN_CITY  \
# 0  Alex Michel            32              NaN       1        Charlottesville
# 1  Alex Michel            32              NaN       1        Charlottesville
# 2  Alex Michel            32              NaN       1        Charlottesville
# 3  Alex Michel            32              NaN       1        Charlottesville
# 4  Alex Michel            32              NaN       1        Charlottesville
#
#   BACHELOR_HOMETOWN_STATE      CONTESTANT  CONTESTANT_AGE  \
# 0                      VA    Amanda Marsh            23.0
# 1                      VA     Trista Rehn            29.0
# 2                      VA  Shannon Oliver            24.0
# 3                      VA             Kim            24.0
# 4                      VA    Cathy Grimes            22.0
#
#                     CONTESTANT_JOB  CONTESTANT_HEIGHT  CONTESTANT_ELIMWEEK  \
# 0                    Event Planner                NaN                  NaN
# 1                Miami Heat Dancer                NaN                  6.0
# 2  Financial Management Consultant                NaN                  5.0
# 3                            Nanny                NaN                  4.0
# 4                 Graduate Student                NaN                  3.0
#
#   CONTESTANT_HOMETOWN_CITY CONTESTANT_HOMETOWN_STATE
# 0                  Chanute                        KS
# 1                    Miami                        FL
# 2                   Dallas                        TX
# 3                    Tempe                        AZ
# 4              Terra Haute                        IN

# %%
the_bachelor.to_csv("the_bachelor.csv")

# %% [markdown]
# ### Bachelorettes

# %%
ette.head()
# Out:
#                      Name   Age          Occupation  \
# 0             Trista Rehn  30.0  Physical therapist
# 1       Meredith Phillips   NaN       Makeup artist
# 2  Jennifer "Jen" Schefft   NaN           Publicist
# 3           DeAnna Pappas   NaN   Real estate agent
# 4          Jillian Harris  29.0   Interior designer
#
#                               Hometown  Season
# 0                Indianapolis, Indiana       1
# 1                                  NaN       2
# 2                                  NaN       3
# 3                                  NaN       4
# 4  Vancouver, British Columbia, Canada       5

# %%
# Split Hometown column
ette[['Hometown_City', 'Hometown_State', 'Other']] = ette['Hometown'].str.split(', ',expand=True)
ette.head()
# can remove Other column
# Out:
#                      Name   Age          Occupation  \
# 0             Trista Rehn  30.0  Physical therapist
# 1       Meredith Phillips   NaN       Makeup artist
# 2  Jennifer "Jen" Schefft   NaN           Publicist
# 3           DeAnna Pappas   NaN   Real estate agent
# 4          Jillian Harris  29.0   Interior designer
#
#                               Hometown  Season Hometown_City  \
# 0                Indianapolis, Indiana       1  Indianapolis
# 1                                  NaN       2           NaN
# 2                                  NaN       3           NaN
# 3                                  NaN       4           NaN
# 4  Vancouver, British Columbia, Canada       5     Vancouver
#
#      Hometown_State   Other
# 0           Indiana    None
# 1               NaN     NaN
# 2               NaN     NaN
# 3               NaN     NaN
# 4  British Columbia  Canada

# %%
# Convert Hometown_State to us state abbreviation if relevant
StateAbbrev = []
for index, row in ette.iterrows():
    #print(row['c1'], row['c2'])
    if row['Hometown_State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['Hometown_State']])
    else: 
        StateAbbrev.append(row['Hometown_State'])
        
ette['Hometown_StateAbbrev'] = StateAbbrev
ette.head()
# Out:
#                      Name   Age          Occupation  \
# 0             Trista Rehn  30.0  Physical therapist
# 1       Meredith Phillips   NaN       Makeup artist
# 2  Jennifer "Jen" Schefft   NaN           Publicist
# 3           DeAnna Pappas   NaN   Real estate agent
# 4          Jillian Harris  29.0   Interior designer
#
#                               Hometown  Season Hometown_City  \
# 0                Indianapolis, Indiana       1  Indianapolis
# 1                                  NaN       2           NaN
# 2                                  NaN       3           NaN
# 3                                  NaN       4           NaN
# 4  Vancouver, British Columbia, Canada       5     Vancouver
#
#      Hometown_State   Other Hometown_StateAbbrev
# 0           Indiana    None                   IN
# 1               NaN     NaN                  NaN
# 2               NaN     NaN                  NaN
# 3               NaN     NaN                  NaN
# 4  British Columbia  Canada     British Columbia

# %%
final_ette = ette[['Name', 'Age', 'Occupation', 'Season', 'Hometown_City', 'Hometown_StateAbbrev']].copy()
final_ette.columns = ['BACHELORETTE', 'BACHELORETTE_AGE', 'BACHELORETTE_JOB', 'SEASON', 'BACHELORETTE_HOMETOWN_CITY', 'BACHELORETTE_HOMETOWN_STATE']
final_ette.head()
# Out:
#              BACHELORETTE  BACHELORETTE_AGE    BACHELORETTE_JOB  SEASON  \
# 0             Trista Rehn              30.0  Physical therapist       1
# 1       Meredith Phillips               NaN       Makeup artist       2
# 2  Jennifer "Jen" Schefft               NaN           Publicist       3
# 3           DeAnna Pappas               NaN   Real estate agent       4
# 4          Jillian Harris              29.0   Interior designer       5
#
#   BACHELORETTE_HOMETOWN_CITY BACHELORETTE_HOMETOWN_STATE
# 0               Indianapolis                          IN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                  Vancouver            British Columbia

# %% [markdown]
# ### Bachelorette Contestants

# %%
ette_cont.head()
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Split Hometown column
ette_cont[['Hometown_City', 'Hometown_State']] = ette_cont['Hometown'].str.split(', ',expand=True)
ette_cont.head()
# can remove Other column
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season  Hometown_City Hometown_State
# 0       1           Vail       Colorado
# 1       1  Hermosa Beach     California
# 2       1     San Rafael     California
# 3       1      Manhattan       New York
# 4       1       Ferndale       Michigan

# %%
# Convert Hometown_State to us state abbreviation if relevant
StateAbbrev = []
for index, row in ette_cont.iterrows():
    #print(row['c1'], row['c2'])
    if row['Hometown_State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['Hometown_State']])
    else: 
        StateAbbrev.append(row['Hometown_State'])
        
ette_cont['Hometown_StateAbbrev'] = StateAbbrev
ette_cont.head()
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season  Hometown_City Hometown_State Hometown_StateAbbrev
# 0       1           Vail       Colorado                   CO
# 1       1  Hermosa Beach     California                   CA
# 2       1     San Rafael     California                   CA
# 3       1      Manhattan       New York                   NY
# 4       1       Ferndale       Michigan                   MI

# %%
final_ette_cont = ette_cont[['Name', 'Age', 'Occupation', 'ElimWeek', 'Season', 'Hometown_City', 'Hometown_StateAbbrev']].copy()
final_ette_cont.columns = ['CONTESTANT', 'CONTESTANT_AGE', 'CONTESTANT_JOB', 'CONTESTANT_ELIMWEEK', 'SEASON', 'CONTESTANT_HOMETOWN_CITY', 'CONTESTANT_HOMETOWN_STATE']
final_ette_cont.head()
# Out:
#       CONTESTANT  CONTESTANT_AGE     CONTESTANT_JOB  CONTESTANT_ELIMWEEK  \
# 0    Ryan Sutter              29        Firefighter                  NaN
# 1  Charlie Maher              28  Financial Analyst                  6.0
# 2           Russ              30             Writer                  5.0
# 3        Greg T.              28           Importer                  4.0
# 4     Bob Guiney              31    Mortgage Broker                  3.0
#
#    SEASON CONTESTANT_HOMETOWN_CITY CONTESTANT_HOMETOWN_STATE
# 0       1                     Vail                        CO
# 1       1            Hermosa Beach                        CA
# 2       1               San Rafael                        CA
# 3       1                Manhattan                        NY
# 4       1                 Ferndale                        MI

# %% [markdown]
# #### Merge final_ette and final_ette_cont on SEASON

# %%
the_bachelorette = final_ette.merge(final_ette_cont, on='SEASON')
print(the_bachelorette.shape)
the_bachelorette.head()
# Out:
# (282, 12)
#   BACHELORETTE  BACHELORETTE_AGE    BACHELORETTE_JOB  SEASON  \
# 0  Trista Rehn              30.0  Physical therapist       1
# 1  Trista Rehn              30.0  Physical therapist       1
# 2  Trista Rehn              30.0  Physical therapist       1
# 3  Trista Rehn              30.0  Physical therapist       1
# 4  Trista Rehn              30.0  Physical therapist       1
#
#   BACHELORETTE_HOMETOWN_CITY BACHELORETTE_HOMETOWN_STATE     CONTESTANT  \
# 0               Indianapolis                          IN    Ryan Sutter
# 1               Indianapolis                          IN  Charlie Maher
# 2               Indianapolis                          IN           Russ
# 3               Indianapolis                          IN        Greg T.
# 4               Indianapolis                          IN     Bob Guiney
#
#    CONTESTANT_AGE     CONTESTANT_JOB  CONTESTANT_ELIMWEEK  \
# 0              29        Firefighter                  NaN
# 1              28  Financial Analyst                  6.0
# 2              30             Writer                  5.0
# 3              28           Importer                  4.0
# 4              31    Mortgage Broker                  3.0
#
#   CONTESTANT_HOMETOWN_CITY CONTESTANT_HOMETOWN_STATE
# 0                     Vail                        CO
# 1            Hermosa Beach                        CA
# 2               San Rafael                        CA
# 3                Manhattan                        NY
# 4                 Ferndale                        MI

# %%
the_bachelorette.to_csv("the_bachelorette.csv")
