# %% [markdown]
# ## Exploratory/Descriptive Statistics

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Occupation Set

# %%
occ = pd.read_csv("ette_cont_occ_group.csv")
occ.head()
# Out:
#                Name  Age               Occupation  \
# 0  Derrick Schuster   27    Construction Engineer
# 1       Zak Waddell   31  Drilling Fluid Engineer
# 2       Clint Arlis   27   Architectural Engineer
# 3   Nick Benvenutti   33      Electrical Engineer
# 4       Will Haduch   26           Civil Engineer
#
#                     Agreement_1                     Hometown  ElimWeek  Season
# 0  Architecture and Engineering  Manhattan Beach, California       1.0       6
# 1  Architecture and Engineering                Dallas, Texas       8.0       9
# 2  Architecture and Engineering            Batavia, Illinois       3.0      11
# 3  Architecture and Engineering           Carthage, Illinois       3.0      12
# 4  Architecture and Engineering      Jersey City, New Jersey       2.0      12

# %%
whole_season = occ.Agreement_1.value_counts()
whole_season.head()
whole_season.plot.bar(x='Agreement_1', y='Value')

# %% [markdown]
# Load in dataset for five-thirty-eight data

# %%
five38 = pd.read_csv("bachelorette_538.csv")

# %% [markdown]
# Look at shape of data

# %%
five38.head()
# remove first line, which is just the header info repeated
five38 = five38.drop([0])
five38.head()
# Out:
#            SHOW SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 1  Bachelorette     13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette     13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette     13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette     13   13_DEAN_U           NaN             R           NaN
# 5  Bachelorette     13   13_ADAM_G           NaN           NaN           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7   ...    DATES-1  \
# 1             R             R           NaN             R   ...        NaN
# 2           NaN           NaN             R             R   ...        NaN
# 3           NaN           NaN             R             R   ...        NaN
# 4             R           NaN           NaN             R   ...        NaN
# 5           NaN           NaN           NaN            ED   ...        NaN
#
#   DATES-2 DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8 DATES-9 DATES-10
# 1     NaN      D6     D13      D1      D7      D1      D1      D1       D1
# 2      D1      D6     D13      D9      D7      D1      D1      D1       D1
# 3     D10      D8     D13      D9      D1      D3      D1      D1      NaN
# 4      D8      D8      D1      D9      D7      D1      D1     NaN      NaN
# 5     D10      D8     D13      D9      D7      D3     NaN     NaN      NaN
#
# [5 rows x 23 columns]

# %%
print("The number of rows of the dataset is: ", len(five38))
print("The number of columns of the dataset is: ", len(five38.columns))
print("The shape of the dataset is: ", five38.shape)
# Out:
# The number of rows of the dataset is:  920
# The number of columns of the dataset is:  23
# The shape of the dataset is:  (920, 23)

# %% [markdown]
# (use df.var.value_counts() ) to count things per person

# %% [markdown]
# ## Bachelor Contestant Data

# %%
bachelor = pd.read_csv("bachelor-contestants.csv")

# %%
bachelor.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season
# 0       Chanute, Kansas     NaN       NaN       1
# 1        Miami, Florida     NaN       6.0       1
# 2         Dallas, Texas     NaN       5.0       1
# 3        Tempe, Arizona     NaN       4.0       1
# 4  Terra Haute, Indiana     NaN       3.0       1

# %%
print("The number of rows of the dataset is: ", len(bachelor))
print("The number of columns of the dataset is: ", len(bachelor.columns))
print("The shape of the dataset is: ", bachelor.shape)
# Out:
# The number of rows of the dataset is:  423
# The number of columns of the dataset is:  7
# The shape of the dataset is:  (423, 7)

# %%
bachelor.dtypes
# Out:
# Name           object
# Age           float64
# Occupation     object
# Hometown       object
# Height        float64
# ElimWeek      float64
# Season          int64
# dtype: object

# %% [markdown]
# Split 'Hometown' column into city and state columns
# Overall and by season:
# Look at age distributions
# Look at height distributions
#
# Look at everything by winner
# What will we have to match on to join with other data?

# %% [markdown]
# ## Histogram of Age (All Seasons)

# %%
bachelor.Age.plot.hist(bins=10)

# %%
for each_season in bachelor.Season.unique():
    seas = bachelor[bachelor.Season == each_season].copy()
    seas['Winner'] = np.where(seas.ElimWeek.isnull(), 1, 0)
    try:
        wa = seas[seas.Winner == 1].Age.get_values()[0]
    except: 
        wa = 0
    print("Season {}:".format(each_season))
    print("Mean Age: {}".format(seas.Age.mean()))
    print("Winner Age: {}".format(wa))
    seas.Age.plot.hist(bins=10, histtype='step')
# Out:
# Season 1:
# Mean Age: 26.4
# Winner Age: 23.0
# Season 2:
# Mean Age: 26.6
# Winner Age: 27.0
# Season 5:
# Mean Age: 25.04
# Winner Age: 22.0
# Season 9:
# Mean Age: 26.307692307692307
# Winner Age: 24.0
# Season 10:
# Mean Age: 25.76
# Winner Age: 26.0
# Season 11:
# Mean Age: 27.0
# Winner Age: 0
# Season 12:
# Mean Age: 26.32
# Winner Age: 22.0
# Season 13:
# Mean Age: 26.92
# Winner Age: 25.0
# Season 14:
# Mean Age: 26.2
# Winner Age: 23.0
# Season 15:
# Mean Age: 26.866666666666667
# Winner Age: 25.0
# Season 16:
# Mean Age: 27.56
# Winner Age: 28.0
# Season 17:
# Mean Age: 26.423076923076923
# Winner Age: 26.0
# Season 18:
# Mean Age: 26.11111111111111
# Winner Age: 26.0
# Season 19:
# Mean Age: 26.833333333333332
# Winner Age: 29.0
# Season 20:
# Mean Age: 25.142857142857142
# Winner Age: 25.0
# Season 21:
# Mean Age: 25.966666666666665
# Winner Age: 31.0

# %%
# change season number to look at individual seasons
seas = bachelor[bachelor.Season == 11].copy()
seas.Age.plot.hist(bins=10)
seas
# Out:
#                          Name   Age                    Occupation  \
# 127             Deanna Pappas  25.0                       Realtor
# 128               Jenni Croft  27.0      Phoenix Suns Cheerleader
# 129              Bettina Bell  27.0                       Realtor
# 130            Sheena Stewart  23.0  Internet marketing executive
# 131         Hillary Reisinger  27.0              Registered nurse
# 132           Kristy Katzmann  29.0                 Acupuncturist
# 133  Estefania "Stephy" Kootz  26.0           Executive assistant
# 134              Jade Beazley  24.0         Boutique sales worker
# 135          McCarten Delaney  26.0               Account manager
# 136           Lindsey Hawkins  25.0                         Model
# 137              Sarah Newlon  23.0                   Bar manager
# 138              Solisa Shoop  25.0                   Esthetician
# 139             Michele Leavy  30.0                       Realtor
# 140            Mallory Simons  24.0                         Nanny
# 141              Erin Gardner  25.0    Publishing sales executive
# 142              Jessica Kiss  27.0                   News anchor
# 143              Juli Gilliam  24.0                   Law student
# 144               Kim Orville  31.0                       Realtor
# 145              Lori Langley  33.0               Biology teacher
# 146           Melissa Buschel  28.0                 Event planner
# 147             Morgan Becker  24.0              Graduate student
# 148           Natalie Velasco  25.0                   Law student
# 149            Regina Doringa  31.0        Account representative
# 150            Tauni Nessler   31.0          Emergency room nurse
# 151               Susan Stein  35.0               Project analyst
#
#                         Hometown  Height  ElimWeek  Season
# 127              Newnan, Georgia     NaN       8.0      11
# 128              Wichita, Kansas     NaN       8.0      11
# 129             Washington, D.C.     NaN       7.0      11
# 130     Walnut Creek, California     NaN       6.0      11
# 131   Philadelphia, Pennsylvania     NaN       5.0      11
# 132             Gurnee, Illinois     NaN       5.0      11
# 133             Atlanta, Georgia     NaN       4.0      11
# 134         Nashville, Tennessee     NaN       4.0      11
# 135      Lemon Grove, California     NaN       4.0      11
# 136            Livonia, Michigan     NaN       3.0      11
# 137           O'Fallon, Illinois     NaN       3.0      11
# 138            Georgetown, Texas     NaN       3.0      11
# 139  South Brunswick, New Jersey     NaN       2.0      11
# 140             Honolulu, Hawaii     NaN       2.0      11
# 141               Tampa, Florida     NaN       2.0      11
# 142           Lady Lake, Florida     NaN       1.0      11
# 143            Chicago, Illinois     NaN       1.0      11
# 144      Woodbridge, Connecticut     NaN       1.0      11
# 145          Annapolis, Maryland     NaN       1.0      11
# 146        Westchester, New York     NaN       1.0      11
# 147               Tempe, Arizona     NaN       1.0      11
# 148           Duncanville, Texas     NaN       1.0      11
# 149        San Diego, California     NaN       1.0      11
# 150    St. Louis Park, Minnesota     NaN       1.0      11
# 151        St. Charles, Illinois     NaN       1.0      11

# %% [markdown]
# Use dictionary to change state abbreviations to Names

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %% [markdown]
# Add in Winner variable

# %%
bachelor.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season
# 0       Chanute, Kansas     NaN       NaN       1
# 1        Miami, Florida     NaN       6.0       1
# 2         Dallas, Texas     NaN       5.0       1
# 3        Tempe, Arizona     NaN       4.0       1
# 4  Terra Haute, Indiana     NaN       3.0       1

# %%
bachelor['Winner'] = np.where(bachelor.ElimWeek.isnull(), 1, 0)
bachelor.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season  Winner
# 0       Chanute, Kansas     NaN       NaN       1       1
# 1        Miami, Florida     NaN       6.0       1       0
# 2         Dallas, Texas     NaN       5.0       1       0
# 3        Tempe, Arizona     NaN       4.0       1       0
# 4  Terra Haute, Indiana     NaN       3.0       1       0

# %% [markdown]
# Let's split up Hometown into City and State

# %%
bachelor[['City', 'State', 'Other']] = bachelor['Hometown'].str.split(', ',expand=True)
bachelor.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season  Winner         City  \
# 0       Chanute, Kansas     NaN       NaN       1       1      Chanute
# 1        Miami, Florida     NaN       6.0       1       0        Miami
# 2         Dallas, Texas     NaN       5.0       1       0       Dallas
# 3        Tempe, Arizona     NaN       4.0       1       0        Tempe
# 4  Terra Haute, Indiana     NaN       3.0       1       0  Terra Haute
#
#      State Other
# 0   Kansas  None
# 1  Florida  None
# 2    Texas  None
# 3  Arizona  None
# 4  Indiana  None

# %%
## need to change State to consistent reference -- change word to two letter abbrev
StateAbbrev = []
for index, row in bachelor.iterrows():
    #print(row['c1'], row['c2'])
    if row['State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['State']])
    else: 
        StateAbbrev.append(row['State'])

print(StateAbbrev[0:10])
# Out:
# ['KS', 'FL', 'TX', 'AZ', 'IN', 'CA', 'CA', 'OK', 'CA', 'NY']

# %%
bachelor['StateAbbrev'] = StateAbbrev
bachelor.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season  Winner         City  \
# 0       Chanute, Kansas     NaN       NaN       1       1      Chanute
# 1        Miami, Florida     NaN       6.0       1       0        Miami
# 2         Dallas, Texas     NaN       5.0       1       0       Dallas
# 3        Tempe, Arizona     NaN       4.0       1       0        Tempe
# 4  Terra Haute, Indiana     NaN       3.0       1       0  Terra Haute
#
#      State Other StateAbbrev
# 0   Kansas  None          KS
# 1  Florida  None          FL
# 2    Texas  None          TX
# 3  Arizona  None          AZ
# 4  Indiana  None          IN

# %% [markdown]
# ## States of Winners

# %%
bach_wins = bachelor[bachelor.Winner == 1].copy()

# %%
bach_wins.StateAbbrev.value_counts(normalize=False).plot.bar()

# %% [markdown]
# California has 3 winners and Texas has 2 winners

# %%
bachelor.StateAbbrev.value_counts(normalize=False)
# Out:
# CA                  57
# TX                  29
# FL                  27
# IL                  21
# NY                  16
# WA                  11
# MI                  10
# OH                   9
# UT                   8
# NJ                   8
# CO                   7
# OK                   7
# TN                   7
# OR                   7
# PA                   7
# AZ                   7
# NC                   7
# SC                   6
# GA                   6
# KS                   5
# MN                   5
# VA                   4
# NV                   4
# CT                   4
# LA                   4
# KY                   4
# MA                   4
# AR                   3
# WI                   2
# HI                   2
# IN                   2
# AL                   2
# British Columbia     2
# ID                   2
# Alberta              2
# RI                   2
# MO                   2
# MD                   2
# ME                   1
# D.C                  1
# MS                   1
# NE                   1
# AK                   1
# Italy                1
# Quebec               1
# D.C.                 1
# IA                   1
# WV                   1
# Name: StateAbbrev, dtype: int64

# %%
bach_wins.Occupation.value_counts(normalize=False).plot.bar()

# %% [markdown]
# Probably want to group occupations into more general topics (or at least decrease the specificity)

# %% [markdown]
# Look at losers in comparison (group by season?)

# %%
bach_lose = bachelor[bachelor.Winner == 0].copy()
bach_lose.head()
# Out:
#              Name   Age                       Occupation  \
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
# 5       Christina  28.0                         Attorney
#
#                Hometown  Height  ElimWeek  Season  Winner         City  \
# 1        Miami, Florida     NaN       6.0       1       0        Miami
# 2         Dallas, Texas     NaN       5.0       1       0       Dallas
# 3        Tempe, Arizona     NaN       4.0       1       0        Tempe
# 4  Terra Haute, Indiana     NaN       3.0       1       0  Terra Haute
# 5    Bonita, California     NaN       3.0       1       0       Bonita
#
#         State Other StateAbbrev
# 1     Florida  None          FL
# 2       Texas  None          TX
# 3     Arizona  None          AZ
# 4     Indiana  None          IN
# 5  California  None          CA

# %%
bach_lose.State.value_counts(normalize=False).plot.bar()

# %%
bach_lose.Occupation.value_counts(normalize=False).plot.bar()

# %% [markdown]
# ## Bachelorette Data

# %%
ette = pd.read_csv("bachelorette-contestants.csv")

# %%
ette.head()
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print("The number of rows of the dataset is: ", len(ette))
print("The number of columns of the dataset is: ", len(ette.columns))
print("The shape of the dataset is: ", ette.shape)
ette.dtypes
# Out:
# The number of rows of the dataset is:  282
# The number of columns of the dataset is:  6
# The shape of the dataset is:  (282, 6)
# Name           object
# Age             int64
# Occupation     object
# Hometown       object
# ElimWeek      float64
# Season          int64
# dtype: object

# %%
for each_season in ette.Season.unique():
    seas = ette[ette.Season == each_season].copy()
    seas['Winner'] = np.where(seas.ElimWeek.isnull(), 1, 0)
    try:
        wa = seas[seas.Winner == 1].Age.get_values()[0]
    except: 
        wa = 0
    print("Season {}:".format(each_season))
    print("Mean Age: {}".format(seas.Age.mean()))
    print("Winner Age: {}".format(wa))
    seas.Age.plot.hist(bins=10, histtype='step')
# Out:
# Season 1:
# Mean Age: 29.72
# Winner Age: 29
# Season 2:
# Mean Age: 29.68
# Winner Age: 29
# Season 4:
# Mean Age: 29.36
# Winner Age: 26
# Season 5:
# Mean Age: 28.533333333333335
# Winner Age: 29
# Season 6:
# Mean Age: 28.16
# Winner Age: 26
# Season 7:
# Mean Age: 29.08
# Winner Age: 34
# Season 8:
# Mean Age: 29.8
# Winner Age: 27
# Season 9:
# Mean Age: 28.68
# Winner Age: 27
# Season 10:
# Mean Age: 29.52
# Winner Age: 29
# Season 11:
# Mean Age: 29.5
# Winner Age: 28
# Season 12:
# Mean Age: 28.307692307692307
# Winner Age: 27

# %%
ette.Age.plot.hist(bins=10)

# %%
ette['Winner'] = np.where(ette.ElimWeek.isnull(), 1, 0)
ette.head()
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season  Winner
# 0       1       1
# 1       1       0
# 2       1       0
# 3       1       0
# 4       1       0

# %%
ette[['City', 'State']] = ette['Hometown'].str.split(', ',expand=True)
ette.head()
# Out:
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season  Winner           City       State
# 0       1       1           Vail    Colorado
# 1       1       0  Hermosa Beach  California
# 2       1       0     San Rafael  California
# 3       1       0      Manhattan    New York
# 4       1       0       Ferndale    Michigan

# %%
## need to change State to consistent reference -- change word to two letter abbrev
StateAbbrev = []
for index, row in ette.iterrows():
    #print(row['c1'], row['c2'])
    if row['State'] in us_state_abbrev: 
        StateAbbrev.append(us_state_abbrev[row['State']])
    else: 
        StateAbbrev.append(row['State'])

print(StateAbbrev[0:10])
ette['StateAbbrev'] = StateAbbrev
ette.head()
# Out:
# ['CO', 'CA', 'CA', 'NY', 'MI', 'IL', 'OH', 'TX', 'TX', 'TX']
#             Name  Age         Occupation                   Hometown  ElimWeek  \
# 0    Ryan Sutter   29        Firefighter             Vail, Colorado       NaN
# 1  Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# 2           Russ   30             Writer     San Rafael, California       5.0
# 3        Greg T.   28           Importer        Manhattan, New York       4.0
# 4     Bob Guiney   31    Mortgage Broker         Ferndale, Michigan       3.0
#
#    Season  Winner           City       State StateAbbrev
# 0       1       1           Vail    Colorado          CO
# 1       1       0  Hermosa Beach  California          CA
# 2       1       0     San Rafael  California          CA
# 3       1       0      Manhattan    New York          NY
# 4       1       0       Ferndale    Michigan          MI

# %%
ette_wins = ette[ette.Winner == 1].copy()
ette_wins.StateAbbrev.value_counts(normalize=False).plot.bar()

# %%
ette.StateAbbrev.value_counts(normalize=False)
# Out:
# CA                  48
# TX                  26
# IL                  19
# NY                  14
# MA                  12
# FL                  11
# CO                  10
# OH                  10
# MI                   8
# NJ                   8
# PA                   7
# MO                   7
# KS                   6
# GA                   6
# WA                   6
# WI                   5
# AZ                   5
# MN                   5
# CT                   5
# NC                   4
# OK                   4
# OR                   3
# RI                   3
# Alberta              3
# TN                   3
# ID                   3
# VA                   3
# IN                   3
# Ontario              3
# IA                   3
# British Columbia     3
# England              2
# MS                   2
# UT                   2
# KY                   2
# MD                   2
# SC                   2
# MT                   2
# VT                   1
# ND                   1
# AL                   1
# Israel               1
# LA                   1
# Brazil               1
# HI                   1
# Venezuela            1
# AK                   1
# Nova Scotia          1
# Argentina            1
# NM                   1
# Name: StateAbbrev, dtype: int64

# %%
ette_wins.Occupation.value_counts(normalize=False).plot.bar()

# %% [markdown]
# ## Bachelor/Bachelorette information

# %%
bachelors = pd.read_csv("bachelors.csv")
bachelors.head()
# Out:
#                Name  Age                   Hometown  Height  Season
# 0       Alex Michel   32  Charlottesville, Virginia     NaN       1
# 1      Aaron Buerge   28           Butler, Missouri     NaN       2
# 2      Jesse Palmer   34           Toronto, Ontario     NaN       5
# 3  Lorenzo Borghese   34               Milan, Italy     NaN       9
# 4      Andy Baldwin   30    Lancaster, Pennsylvania     NaN      10

# %%
print("The number of rows of the dataset is: ", len(bachelors))
print("The number of columns of the dataset is: ", len(bachelors.columns))
print("The shape of the dataset is: ", bachelors.shape)
bachelors.dtypes
# Out:
# The number of rows of the dataset is:  16
# The number of columns of the dataset is:  5
# The shape of the dataset is:  (16, 5)
# Name         object
# Age           int64
# Hometown     object
# Height      float64
# Season        int64
# dtype: object

# %%
bachelors.Age.plot.hist(bins=10)

# %% [markdown]
# Look at Bachelor Age vs. Contestant Age

# %%
bach_wins.head()
# Out:
#                    Name   Age           Occupation  \
# 0          Amanda Marsh  23.0        Event Planner
# 25   Helene Eksterowicz  27.0  School Psychologist
# 50       Jessica Bowlin  22.0              Student
# 75      Jennifer Wilson  24.0              Teacher
# 102         Tessa Horst  26.0        Social Worker
#
#                          Hometown  Height  ElimWeek  Season  Winner  \
# 0                 Chanute, Kansas     NaN       NaN       1       1
# 25         Gloucester, New Jersey     NaN       NaN       2       1
# 50   Huntington Beach, California     NaN       NaN       5       1
# 75        Pembroke Pines, Florida     NaN       NaN       9       1
# 102     San Francisco, California     NaN       NaN      10       1
#
#                  City       State Other StateAbbrev
# 0             Chanute      Kansas  None          KS
# 25         Gloucester  New Jersey  None          NJ
# 50   Huntington Beach  California  None          CA
# 75     Pembroke Pines     Florida  None          FL
# 102     San Francisco  California  None          CA

# %%
compare_winners = bachelors.merge(bach_wins, on='Season', suffixes=('_bachelor', '_contestant'))
compare_winners.head()
# Out:
#       Name_bachelor  Age_bachelor          Hometown_bachelor  Height_bachelor  \
# 0       Alex Michel            32  Charlottesville, Virginia              NaN
# 1      Aaron Buerge            28           Butler, Missouri              NaN
# 2      Jesse Palmer            34           Toronto, Ontario              NaN
# 3  Lorenzo Borghese            34               Milan, Italy              NaN
# 4      Andy Baldwin            30    Lancaster, Pennsylvania              NaN
#
#    Season     Name_contestant  Age_contestant           Occupation  \
# 0       1        Amanda Marsh            23.0        Event Planner
# 1       2  Helene Eksterowicz            27.0  School Psychologist
# 2       5      Jessica Bowlin            22.0              Student
# 3       9     Jennifer Wilson            24.0              Teacher
# 4      10         Tessa Horst            26.0        Social Worker
#
#             Hometown_contestant  Height_contestant  ElimWeek  Winner  \
# 0               Chanute, Kansas                NaN       NaN       1
# 1        Gloucester, New Jersey                NaN       NaN       1
# 2  Huntington Beach, California                NaN       NaN       1
# 3       Pembroke Pines, Florida                NaN       NaN       1
# 4     San Francisco, California                NaN       NaN       1
#
#                City       State Other StateAbbrev
# 0           Chanute      Kansas  None          KS
# 1        Gloucester  New Jersey  None          NJ
# 2  Huntington Beach  California  None          CA
# 3    Pembroke Pines     Florida  None          FL
# 4     San Francisco  California  None          CA

# %%
# look at the age of the Bachelor compared with who they chose as the winner
compare_winners['Age_Diff'] = compare_winners['Age_bachelor'] - compare_winners['Age_contestant']
compare_winners.head()
# Out:
#       Name_bachelor  Age_bachelor          Hometown_bachelor  Height_bachelor  \
# 0       Alex Michel            32  Charlottesville, Virginia              NaN
# 1      Aaron Buerge            28           Butler, Missouri              NaN
# 2      Jesse Palmer            34           Toronto, Ontario              NaN
# 3  Lorenzo Borghese            34               Milan, Italy              NaN
# 4      Andy Baldwin            30    Lancaster, Pennsylvania              NaN
#
#    Season     Name_contestant  Age_contestant           Occupation  \
# 0       1        Amanda Marsh            23.0        Event Planner
# 1       2  Helene Eksterowicz            27.0  School Psychologist
# 2       5      Jessica Bowlin            22.0              Student
# 3       9     Jennifer Wilson            24.0              Teacher
# 4      10         Tessa Horst            26.0        Social Worker
#
#             Hometown_contestant  Height_contestant  ElimWeek  Winner  \
# 0               Chanute, Kansas                NaN       NaN       1
# 1        Gloucester, New Jersey                NaN       NaN       1
# 2  Huntington Beach, California                NaN       NaN       1
# 3       Pembroke Pines, Florida                NaN       NaN       1
# 4     San Francisco, California                NaN       NaN       1
#
#                City       State Other StateAbbrev  Age_Diff
# 0           Chanute      Kansas  None          KS       9.0
# 1        Gloucester  New Jersey  None          NJ       1.0
# 2  Huntington Beach  California  None          CA      12.0
# 3    Pembroke Pines     Florida  None          FL      10.0
# 4     San Francisco  California  None          CA       4.0

# %%
plot_comp = compare_winners[(compare_winners.Age_Diff.notnull()) & (compare_winners.Season != 21)]
plot_comp.plot.bar(x='Season', y='Age_Diff')

# %%
print('Mean Age Difference Between Bachelor and Winner: {} years'.format(np.mean(plot_comp['Age_Diff'])))
print('Min Age Difference Between Bachelor and Winner: {} years'.format(np.min(plot_comp['Age_Diff'])))
print('Max Age Difference Between Bachelor and Winner: {} years'.format(np.max(plot_comp['Age_Diff'])))
# Out:
# Mean Age Difference Between Bachelor and Winner: 5.785714285714286 years
# Min Age Difference Between Bachelor and Winner: 0.0 years
# Max Age Difference Between Bachelor and Winner: 12.0 years

# %% [markdown]
# ## Look at the same thing with The Bachelorette

# %%
ettes = pd.read_csv("bachelorettes.csv")
ettes.head()
# Out:
#                      Name   Age          Occupation  \
# 0             Trista Rehn  30.0  Physical therapist
# 1       Meredith Phillips   NaN       Makeup artist
# 2  Jennifer "Jen" Schefft   NaN           Publicist
# 3           DeAnna Pappas   NaN   Real estate agent
# 4          Jillian Harris  29.0   Interior designer
#
#                               Hometown  Season
# 0                Indianapolis, Indiana       1
# 1                                  NaN       2
# 2                                  NaN       3
# 3                                  NaN       4
# 4  Vancouver, British Columbia, Canada       5

# %%
print("The number of rows of the dataset is: ", len(ettes))
print("The number of columns of the dataset is: ", len(ettes.columns))
print("The shape of the dataset is: ", ettes.shape)
ettes.dtypes
# Out:
# The number of rows of the dataset is:  13
# The number of columns of the dataset is:  5
# The shape of the dataset is:  (13, 5)
# Name           object
# Age           float64
# Occupation     object
# Hometown       object
# Season          int64
# dtype: object

# %%
ettes.Age.plot.hist(bins=10)

# %%
comp_win = ettes.merge(ette_wins, on='Season', suffixes=('_bachelorette', '_contestant'))
comp_win.head()
# Out:
#    Name_bachelorette  Age_bachelorette      Occupation_bachelorette  \
# 0        Trista Rehn              30.0           Physical therapist
# 1  Meredith Phillips               NaN                Makeup artist
# 2      DeAnna Pappas               NaN            Real estate agent
# 3     Jillian Harris              29.0            Interior designer
# 4     Ali Fedotowsky              25.0  Advertising account manager
#
#                  Hometown_bachelorette  Season   Name_contestant  \
# 0                Indianapolis, Indiana       1       Ryan Sutter
# 1                                  NaN       2         Ian McKee
# 2                                  NaN       4    Jesse Csincsak
# 3  Vancouver, British Columbia, Canada       5      Ed Swiderski
# 4                        Massachusetts       6  Roberto Martinez
#
#    Age_contestant     Occupation_contestant     Hometown_contestant  ElimWeek  \
# 0              29               Firefighter          Vail, Colorado       NaN
# 1              29     Equity Research Sales      New York, New York       NaN
# 2              26  Professional snowboarder  Breckenridge, Colorado       NaN
# 3              29     Technology Consultant        Monroe, Michigan       NaN
# 4              26           Insurance Agent          Tampa, Florida       NaN
#
#    Winner          City     State StateAbbrev
# 0       1          Vail  Colorado          CO
# 1       1      New York  New York          NY
# 2       1  Breckenridge  Colorado          CO
# 3       1        Monroe  Michigan          MI
# 4       1         Tampa   Florida          FL

# %%
# look at the age of the Bachelorette compared with who they chose as the winner
comp_win['Age_Diff'] = comp_win['Age_bachelorette'] - comp_win['Age_contestant']
comp_win.head()
# Out:
#    Name_bachelorette  Age_bachelorette      Occupation_bachelorette  \
# 0        Trista Rehn              30.0           Physical therapist
# 1  Meredith Phillips               NaN                Makeup artist
# 2      DeAnna Pappas               NaN            Real estate agent
# 3     Jillian Harris              29.0            Interior designer
# 4     Ali Fedotowsky              25.0  Advertising account manager
#
#                  Hometown_bachelorette  Season   Name_contestant  \
# 0                Indianapolis, Indiana       1       Ryan Sutter
# 1                                  NaN       2         Ian McKee
# 2                                  NaN       4    Jesse Csincsak
# 3  Vancouver, British Columbia, Canada       5      Ed Swiderski
# 4                        Massachusetts       6  Roberto Martinez
#
#    Age_contestant     Occupation_contestant     Hometown_contestant  ElimWeek  \
# 0              29               Firefighter          Vail, Colorado       NaN
# 1              29     Equity Research Sales      New York, New York       NaN
# 2              26  Professional snowboarder  Breckenridge, Colorado       NaN
# 3              29     Technology Consultant        Monroe, Michigan       NaN
# 4              26           Insurance Agent          Tampa, Florida       NaN
#
#    Winner          City     State StateAbbrev  Age_Diff
# 0       1          Vail  Colorado          CO       1.0
# 1       1      New York  New York          NY       NaN
# 2       1  Breckenridge  Colorado          CO       NaN
# 3       1        Monroe  Michigan          MI       0.0
# 4       1         Tampa   Florida          FL      -1.0

# %%
plot_comp2 = comp_win[comp_win.Age_Diff.notnull()]
plot_comp2.plot.bar(x='Season', y='Age_Diff')

# %%
print('Mean Age Difference Between Bachelorette and Winner: {} years'.format(np.mean(plot_comp2['Age_Diff'])))
print('Min Age Difference Between Bachelorette and Winner: {} years'.format(np.min(plot_comp2['Age_Diff'])))
print('Max Age Difference Between Bachelorette and Winner: {} years'.format(np.max(plot_comp2['Age_Diff'])))
# Out:
# Mean Age Difference Between Bachelorette and Winner: -0.5714285714285714 years
# Min Age Difference Between Bachelorette and Winner: -3.0 years
# Max Age Difference Between Bachelorette and Winner: 1.0 years
